# %%
import os, sys
import pandas as pd
import numpy as np
from scipy import stats
from dotenv import load_dotenv
rpath = os.path.abspath('/home/user/Documents/10/w12/Semantic Image and Text Alignment')

if rpath not in sys.path:
    sys.path.insert(0, rpath)
load_dotenv()
rpath
# Out:
# '/home/user/Documents/10/w12/Semantic Image and Text Alignment'

# %%
csv_file_path = rpath + '/data/performance_data.csv'


df = pd.read_csv(csv_file_path)

# %%
df
# Out:
#                                                game_id  \
# 0                     bfbf7a2b7ac635e67877b1ab87fd6629
# 1                     945010afbf9a55bbdffcb0895f946155
# 2                     e68e20f592457b875ce29757ab855dfe
# 3                    adunit-nestle-purina-friskies-mob
# 4    adunit-lionsgate-uwomt-user-slider-sensory-vid...
# ..                                                 ...
# 900                   2443bd3b890824acecbe32659b9a1246
# 901                   7ed73c1cc404f9956d26c5f58de72b2f
# 902                   90455f5ace15860874965eabd081b6f2
# 903                    adunit-chevy-hotspot-cpe-av-mpu
# 904  adunit-facebook-conversational-commerce-3-0-vn...
#
#                                           preview_link        ER       CTR
# 0    https://s3.us-east-1.amazonaws.com/a.futureadl...  0.209269  0.058438
# 1    https://s3.us-east-1.amazonaws.com/a.futureadl...  0.274552  0.074731
# 2    https://s3.us-east-1.amazonaws.com/a.futureadl...  0.103688  0.042228
# 3    https://s3.ap-southeast-1.amazonaws.com/a.futu...  0.136963  0.005393
# 4    https://s3.us-west-1.amazonaws.com/a.futureadl...  0.114208  0.016443
# ..                                                 ...       ...       ...
# 900  https://s3.eu-west-1.amazonaws.com/a.futureadl...  0.365997  0.008790
# 901  https://s3.us-east-1.amazonaws.com/a.futureadl...  0.103055  0.043215
# 902  https://s3.ap-southeast-1.amazonaws.com/a.futu...  0.191425  0.038692
# 903  https://s3.us-east-1.amazonaws.com/a.futureadl...  0.073058  0.000057
# 904  https://s3.ap-southeast-1.amazonaws.com/a.futu...  0.085290  0.000000
#
# [905 rows x 4 columns]

# %%
def summarize_data(df):
    
   
    numeric_stats = df.describe().transpose()
    missing_values = df.isnull().sum()
    summary_df = pd.DataFrame(index=df.columns)
    summary_df['Data Type'] = df.dtypes
    summary_df['Missing Values'] = missing_values
    summary_df['Unique Values'] = df.nunique()
    summary_df = summary_df.join(numeric_stats[['mean', 'std', 'min', '25%', '50%', '75%', 'max']])
    # df.describe().T
    return summary_df

# %%
summarize_data(df)
# Out:
#              Data Type  Missing Values  Unique Values      mean       std  \
# game_id        float64             905              0       NaN       NaN
# preview_link   float64             905              0       NaN       NaN
# ER             float64               0            871  0.136318  0.091524
# CTR            float64               0            851  0.034466  0.036967
#
#               min       25%       50%       75%       max
# game_id       NaN       NaN       NaN       NaN       NaN
# preview_link  NaN       NaN       NaN       NaN       NaN
# ER            0.0  0.070338  0.118624  0.190722  0.524498
# CTR           0.0  0.007926  0.024537  0.047796  0.297410

# %%
def perform_value_counts(df):
    value_counts_dict = {}
    for column_name in df.columns:
        value_counts = df[column_name].value_counts().reset_index()
        value_counts.columns = ['Value', 'Count']
        value_counts_dict[column_name] = value_counts.set_index('Value')['Count']  # Setting 'Value' as index and 'Count' as values
    
    return pd.DataFrame(value_counts_dict)

# %%
perform_value_counts(df)
# Out:
#           game_id  preview_link    ER   CTR
# Value
# 0.000000      NaN           NaN  34.0  55.0
# 0.000015      NaN           NaN   NaN   1.0
# 0.000047      NaN           NaN   NaN   1.0
# 0.000049      NaN           NaN   NaN   1.0
# 0.000057      NaN           NaN   NaN   1.0
# ...           ...           ...   ...   ...
# 0.429701      NaN           NaN   1.0   NaN
# 0.439367      NaN           NaN   1.0   NaN
# 0.440421      NaN           NaN   1.0   NaN
# 0.446696      NaN           NaN   1.0   NaN
# 0.524498      NaN           NaN   1.0   NaN
#
# [1719 rows x 4 columns]

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /home/user/anaconda3/lib/python3.11/site-packages (10.2.0)

# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
image_path = rpath + '/data/adludio storyboard examples/western-union-philippines_FS_600x900_storyboard.png'
image = Image.open(image_path)

plt.figure(figsize=(8, 8))
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
import numpy as np

# Example: Get image statistics
image_array = np.array(image)
height, width, channels = image_array.shape
data_type = image_array.dtype

print(f"Image dimensions: {width} x {height}")
print(f"Color channels: {channels}")
print(f"Data type: {data_type}")
# Out:
# Image dimensions: 3859 x 2171
# Color channels: 4
# Data type: uint8

# %%
# Example: Plot histogram of pixel intensities
if channels == 1:
    plt.hist(image_array.ravel(), bins=256, range=(0, 255), density=True)
    plt.title('Histogram of Pixel Intensities')
    plt.xlabel('Pixel Intensity')
    plt.ylabel('Normalized Frequency')
    plt.show()
else:
    colors = ('r', 'g', 'b')
    for i, color in enumerate(colors):
        hist, bins = np.histogram(image_array[:,:,i].ravel(), bins=256, range=(0, 255), density=True)
        plt.plot(hist, color=color, alpha=0.7, label=color)
    plt.title('Histogram of Color Channels')
    plt.xlabel('Pixel Intensity')
    plt.ylabel('Normalized Frequency')
    plt.legend()
    plt.show()
